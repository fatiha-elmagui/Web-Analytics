# %% [markdown]
# # witter Scrapping

# %%
# import libraries
import tweepy 
import pandas as pd
import csv 
import os 
import numpy as np
import time

# %%
consumer_key = "MvrcsAV1DM6pjmq9CqieHGJ7e"
consumer_secret = "CIwA7Os2aAyE3y2tBUR9lDdAqCiAf9M4F9reli50HcVtUiLpw9"
access_token = "1339569016466255874-1koWsUKNn9f8mhZXWmj4dw7cjtJHxW"
access_token_secret = "pEubyqL7rKkablRlXOx7MxLEtFyMQCgBi8EJwBfiu0pLC"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
text_query = 'Tl9i7' + "-filter:retweets" #select subject to search for
count = 150 #number of tweets to extract
try:
 # Creation of query method using parameters # you can add date and lang 
 tweets = tweepy.Cursor(api.search ,q=text_query).items(count)
 
 # Pulling information from tweets iterable object
 # listing tweets 
 tweets_list = []
 for tweet in tweets:
    tweets_list.append([tweet.user.screen_name, tweet.text])
    username=tweet.user.screen_name
    text=tweet.text
    location=tweet.geo
 for i in range (0, len(tweets_list)):
     print(tweets_list[i])
     print('-------------------------')

except BaseException as e:
    print('failed on_status,',str(e))
    time.sleep(3)
# Out:
# ['zyadelassad33', '@meee_sofia Ghda m3a 9 bghaw idiroulina tl9i7 hhhhhhhhhh']
# -------------------------
# ['zyadelassad33', 'Ayzr3o fina lma droubini wigoulik tl9i7 wladl97ab']
# -------------------------
# ['zyadelassad33', '@ussalbsr @7ach7ouch_ Hantouma atchoufi dik lw9ita ankhrj ana o omar ndrbo jwanate 3la maysaliw nass tl9i7 hhhhhh']
# -------------------------
# ['zyadelassad33', '@chair_salma Hhhhhhhh ghadirih makayn la tl9i7 la walo aydkhloulina gha lma droubini hhhhhhhhhhhhhhhh']
# -------------------------
# ['chair_salma', 'Awili hta bghit ndir mchro3 nbda nbi3 mo39im u huma ydiro tl9i7 https://t.co/sNNn4uD08k']
# -------------------------
# ['zyadelassad33', '@ussalbsr @7ach7ouch_ Galik ghda tl9i7 makaymrgouch wladl97ab']
# -------------------------
# ['zyadelassad33', 'Ghan3yite lgrand master kifach tl9i7 awldl97ba galya talchhre 2?????']
# -------------------------
# ['zyadelassad33', 'Drte vocal sjlte fih l7arissa l3ama kathdre bnte l97ba hhhhhhhhhhhhhhhhhhhhhh galtlik tl9i7 ghda m3a 9 hak 7wini al97ba azb']
# -------------------------
# ['HiIsBah', '@zyadelassad33 hada test magalouch tl9i7']
# -------------------------
# ['zyadelassad33', 'Ila drte tl9i7 aji 7wiwni hhhhhhhhhhhhhhhhhhhhhhhhhh']
# -------------------------
# ['zyadelassad33', 'Zabi zabi zabi zabi ladrte tl9i7']
# -------------------------
# ['HiIsBah', '@omarcherkawi33 @zyadelassad33 Bda tl9i7']
# -------------------------

# %%
#adding tweets to a dataframe 
BDD_tweets=pd.DataFrame(tweets_list ,columns=['username', 'tweet'])
# Store dataframe in csv 
# Define working path and filename
path = "C://Users/hp/Downloads"
filename ="tweets.csv"
BDD_tweets.to_csv(filename, index = False)
print (BDD_tweets)
# Out:
#          username                                              tweet
# 0   zyadelassad33  @meee_sofia Ghda m3a 9 bghaw idiroulina tl9i7 ...
# 1   zyadelassad33  Ayzr3o fina lma droubini wigoulik tl9i7 wladl97ab
# 2   zyadelassad33  @ussalbsr @7ach7ouch_ Hantouma atchoufi dik lw...
# 3   zyadelassad33  @chair_salma Hhhhhhhh ghadirih makayn la tl9i7...
# 4     chair_salma  Awili hta bghit ndir mchro3 nbda nbi3 mo39im u...
# 5   zyadelassad33  @ussalbsr @7ach7ouch_ Galik ghda tl9i7 makaymr...
# 6   zyadelassad33  Ghan3yite lgrand master kifach tl9i7 awldl97ba...
# 7   zyadelassad33  Drte vocal sjlte fih l7arissa l3ama kathdre bn...
# 8         HiIsBah           @zyadelassad33 hada test magalouch tl9i7
# 9   zyadelassad33  Ila drte tl9i7 aji 7wiwni hhhhhhhhhhhhhhhhhhhh...
# 10  zyadelassad33                   Zabi zabi zabi zabi ladrte tl9i7
# 11        HiIsBah           @omarcherkawi33 @zyadelassad33 Bda tl9i7

# %%
text_query = 'li9a7' + "-filter:retweets" #select subject to search for
count = 150 #number of tweets to extract
try:
 # Creation of query method using parameters # you can add date and lang 
 tweets = tweepy.Cursor(api.search ,q=text_query).items(count)
 
 # Pulling information from tweets iterable object
 # listing tweets 
 tweets_list = []
 for tweet in tweets:
    tweets_list.append([tweet.user.screen_name, tweet.text])
    username=tweet.user.screen_name
    text=tweet.text
    location=tweet.geo
 for i in range (0, len(tweets_list)):
     print(tweets_list[i])
     print('-------------------------')

except BaseException as e:
    print('failed on_status,',str(e))
    time.sleep(3)
# Out:
# ['HoussineDotcom', 'Li9a7 bgha lbrakha']
# -------------------------
# ['HiIsBah', '@easyas0 hada li9a7']
# -------------------------
# ['hihilist', 'Nswl 3la moukwinat dual had l7rira ou manswlch 3la dyal li9a7 https://t.co/ehaZqPZoHk']
# -------------------------
# ['Amine19O', '@Docteur_WHOO L congé inchallah bi idni allah men be3d ma yji li9a7']
# -------------------------
# ['ghiwa7dzbi', 'zbi chabab hna wlh mabaghayin chi dwa d corona wla li9a7 wla zbi ila kayn chi li9a7 tay5llik thdr m3a lbnat mr7ba']
# -------------------------
# ['notcidji', 'aydiro li9a7 f drarga hhhhhhhhhhhhhhhhhh']
# -------------------------
# ['NaimHamdi8', 'Yomkino an najid 3ilaj il vrus .... wa lakin 5alfiyat li9a7 tkono 3al mada tawil 5atira ou yomkin ana tousbib fi ta… https://t.co/4fz712vKOw']
# -------------------------
# ['HiIsBah', '@zyadelassad33 sa7bi srbilna li9a7 rah 3ndi frd dsvt ghdda']
# -------------------------
# ['omarcherkawi33', 'Li9a7 favour? ofma8rib? Smthg not right']
# -------------------------
# ['omarcherkawi33', '9alk ghayjrbo fina bash yshufu li9a7 wash 5adam zwaml']
# -------------------------
# ['omarcherkawi33', '@Hisraeb @zyadelassad33 😂 ghda a zbi ghayemlona li9a7 wtf']
# -------------------------
# ['DDA_3li', 'Wa 9hertouna b lhedra ? \nDaba kayn chi li9a7 oula walou ?? https://t.co/seSycOyKFh https://t.co/zngWr5T76d']
# -------------------------

# %%
#adding tweets to a dataframe 
BDD_tweets=pd.DataFrame(tweets_list ,columns=['username', 'tweet'])
# Store dataframe in csv 
# Define working path and filename
path = "C://Users/hp/Downloads"
filename ="_subject_tweets.csv"
BDD_tweets.to_csv(filename, index = False)
print (BDD_tweets)
# Out:
#           username                                              tweet
# 0   HoussineDotcom                                 Li9a7 bgha lbrakha
# 1          HiIsBah                                @easyas0 hada li9a7
# 2         hihilist  Nswl 3la moukwinat dual had l7rira ou manswlch...
# 3         Amine19O  @Docteur_WHOO L congé inchallah bi idni allah ...
# 4       ghiwa7dzbi  zbi chabab hna wlh mabaghayin chi dwa d corona...
# 5         notcidji           aydiro li9a7 f drarga hhhhhhhhhhhhhhhhhh
# 6       NaimHamdi8  Yomkino an najid 3ilaj il vrus .... wa lakin 5...
# 7          HiIsBah  @zyadelassad33 sa7bi srbilna li9a7 rah 3ndi fr...
# 8   omarcherkawi33            Li9a7 favour? ofma8rib? Smthg not right
# 9   omarcherkawi33  9alk ghayjrbo fina bash yshufu li9a7 wash 5ada...
# 10  omarcherkawi33  @Hisraeb @zyadelassad33 😂 ghda a zbi ghayemlon...
# 11         DDA_3li  Wa 9hertouna b lhedra ? \nDaba kayn chi li9a7 ...

# %% [markdown]
# # NLP

# %%
#download libraries
import re
import nltk
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option("display.max_colwidth",200)
warnings.filterwarnings("ignore",category=DeprecationWarning)
# %matplotlib inline

# %%
#read dataset
data=pd.read_csv("C:/Users/hp/Downloads/_subject_tweets.csv")
data1=pd.read_csv("C:/Users/hp/Downloads/tweets.csv")
data.head()
# Out:
#      username  \
# 0    hihilist
# 1    Amine19O
# 2    notcidji
# 3  NaimHamdi8
# 4     HiIsBah
#
#                                                                                                                   tweet  \
# 0                                                         Nswl 3la moukwinat dual had l7rira ou manswlch 3la dyal li9a7
# 1                                                   @Docteur_WHOO L congé inchallah bi idni allah men be3d ma yji li9a7
# 2                                                                              aydiro li9a7 f drarga hhhhhhhhhhhhhhhhhh
# 3  Yomkino an najid 3ilaj il vrus .... wa lakin 5alfiyat li9a7 tkono 3al mada tawil 5atira ou yomkin ana tousbib fi ta…
# 4                                                            @zyadelassad33 sa7bi srbilna li9a7 rah 3ndi frd dsvt ghdda
#
#    label
# 0      0
# 1      1
# 2      0
# 3      0
# 4      2

# %% [markdown]
# # Data Inspection

# %%
# check some negative twweets
data[data['label']==0].head(5)
# Out:
#          username  \
# 0        hihilist
# 2        notcidji
# 3      NaimHamdi8
# 5  omarcherkawi33
# 6  omarcherkawi33
#
#                                                                                                                   tweet  \
# 0                                                         Nswl 3la moukwinat dual had l7rira ou manswlch 3la dyal li9a7
# 2                                                                              aydiro li9a7 f drarga hhhhhhhhhhhhhhhhhh
# 3  Yomkino an najid 3ilaj il vrus .... wa lakin 5alfiyat li9a7 tkono 3al mada tawil 5atira ou yomkin ana tousbib fi ta…
# 5                                                                               Li9a7 favour? ofma8rib? Smthg not right
# 6                                                                       9alk ghayjrbo fina bash yshufu li9a7 wash 5adam
#
#    label
# 0      0
# 2      0
# 3      0
# 5      0
# 6      0

# %%
# check some positive twweets
data[data['label']==1].head(5)
# Out:
#    username  \
# 1  Amine19O
#
#                                                                  tweet  label
# 1  @Docteur_WHOO L congé inchallah bi idni allah men be3d ma yji li9a7      1

# %%
# check some neutral twweets
data[data['label']==2].head(5)
# Out:
#   username                                                       tweet  label
# 4  HiIsBah  @zyadelassad33 sa7bi srbilna li9a7 rah 3ndi frd dsvt ghdda      2

# %%
#dimensions of the train and test datasets
data.shape,data1.shape
# Out:
# ((9, 3), (11, 3))

# %%
# label disticution at the train dataset
data["label"].value_counts()
# Out:
# 0    7
# 2    1
# 1    1
# Name: label, dtype: int64

# %%
# let's check the distribution of length of tweets in terms of words in train and test datasets
length_tr= data['tweet'].str.len()
length_te= data1['tweet'].str.len()
plt.hist(length_tr,bins=20,label="train tweets")
plt.hist(length_te,bins=20,label="test tweets")
plt.legend()
plt.show()

# %% [markdown]
# # Data Cleaning

# %%
#combine the training and testing datasets
combine= data.append(data1, ignore_index=True)
combine.shape
# Out:
# (20, 3)

# %%
# remove unwanted text patterns from the tweets
def remove(text_input,pattern):
    r=re.findall(pattern,text_input)
    for i in r:
        text_input=re.sub(i,'',text_input)
    return text_input

# %%
# remove twitter handlers(@user)
# we create a column containing the cleaned tweets
combine['cleaned_tweets']=np.vectorize(remove)(combine['tweet'],"@[\w]*")
combine.head(5)
# Out:
#      username  \
# 0    hihilist
# 1    Amine19O
# 2    notcidji
# 3  NaimHamdi8
# 4     HiIsBah
#
#                                                                                                                   tweet  \
# 0                                                         Nswl 3la moukwinat dual had l7rira ou manswlch 3la dyal li9a7
# 1                                                   @Docteur_WHOO L congé inchallah bi idni allah men be3d ma yji li9a7
# 2                                                                              aydiro li9a7 f drarga hhhhhhhhhhhhhhhhhh
# 3  Yomkino an najid 3ilaj il vrus .... wa lakin 5alfiyat li9a7 tkono 3al mada tawil 5atira ou yomkin ana tousbib fi ta…
# 4                                                            @zyadelassad33 sa7bi srbilna li9a7 rah 3ndi frd dsvt ghdda
#
#    label  \
# 0      0
# 1      1
# 2      0
# 3      0
# 4      2
#
#                                                                                                          cleaned_tweets
# 0                                                         Nswl 3la moukwinat dual had l7rira ou manswlch 3la dyal li9a7
# 1                                                                 L congé inchallah bi idni allah men be3d ma yji li9a7
# 2                                                                              aydiro li9a7 f drarga hhhhhhhhhhhhhhhhhh
# 3  Yomkino an najid 3ilaj il vrus .... wa lakin 5alfiyat li9a7 tkono 3al mada tawil 5atira ou yomkin ana tousbib fi ta…
# 4                                                                           sa7bi srbilna li9a7 rah 3ndi frd dsvt ghdda

# %%
# remove punctuations, numbers, and special Characters
#replace eveything  except characters and hashtags with spaces
combine['cleaned_tweets']=combine['cleaned_tweets'].str.replace(r"[-()\"#/@;:<>{}`+=~|.!?,]"," ")
combine.head(5)
# Out:
#      username  \
# 0    hihilist
# 1    Amine19O
# 2    notcidji
# 3  NaimHamdi8
# 4     HiIsBah
#
#                                                                                                                   tweet  \
# 0                                                         Nswl 3la moukwinat dual had l7rira ou manswlch 3la dyal li9a7
# 1                                                   @Docteur_WHOO L congé inchallah bi idni allah men be3d ma yji li9a7
# 2                                                                              aydiro li9a7 f drarga hhhhhhhhhhhhhhhhhh
# 3  Yomkino an najid 3ilaj il vrus .... wa lakin 5alfiyat li9a7 tkono 3al mada tawil 5atira ou yomkin ana tousbib fi ta…
# 4                                                            @zyadelassad33 sa7bi srbilna li9a7 rah 3ndi frd dsvt ghdda
#
#    label  \
# 0      0
# 1      1
# 2      0
# 3      0
# 4      2
#
#                                                                                                          cleaned_tweets
# 0                                                         Nswl 3la moukwinat dual had l7rira ou manswlch 3la dyal li9a7
# 1                                                                 L congé inchallah bi idni allah men be3d ma yji li9a7
# 2                                                                              aydiro li9a7 f drarga hhhhhhhhhhhhhhhhhh
# 3  Yomkino an najid 3ilaj il vrus      wa lakin 5alfiyat li9a7 tkono 3al mada tawil 5atira ou yomkin ana tousbib fi ta…
# 4                                                                           sa7bi srbilna li9a7 rah 3ndi frd dsvt ghdda

# %%
#remove short words
#remove all the words having length 3 or less
combine['cleaned_tweets']=combine['cleaned_tweets'].apply(lambda x:' '.join([j for j in x.split() if len(j)>3]))
combine.head(5)
# Out:
#      username  \
# 0    hihilist
# 1    Amine19O
# 2    notcidji
# 3  NaimHamdi8
# 4     HiIsBah
#
#                                                                                                                   tweet  \
# 0                                                         Nswl 3la moukwinat dual had l7rira ou manswlch 3la dyal li9a7
# 1                                                   @Docteur_WHOO L congé inchallah bi idni allah men be3d ma yji li9a7
# 2                                                                              aydiro li9a7 f drarga hhhhhhhhhhhhhhhhhh
# 3  Yomkino an najid 3ilaj il vrus .... wa lakin 5alfiyat li9a7 tkono 3al mada tawil 5atira ou yomkin ana tousbib fi ta…
# 4                                                            @zyadelassad33 sa7bi srbilna li9a7 rah 3ndi frd dsvt ghdda
#
#    label  \
# 0      0
# 1      1
# 2      0
# 3      0
# 4      2
#
#                                                                cleaned_tweets
# 0                                             moukwinat l7rira manswlch li9a7
# 1                                                 congé inchallah allah li9a7
# 2                                      aydiro li9a7 drarga hhhhhhhhhhhhhhhhhh
# 3  Yomkino najid 3ilaj lakin 5alfiyat li9a7 tkono tawil 5atira yomkin tousbib
# 4                                                   sa7bi srbilna li9a7 ghdda

# %%
#Tokenization
tokenize_tweets=combine['cleaned_tweets'].apply(lambda x: x.split())
tokenize_tweets.head(5)
# Out:
# 0                                                      [moukwinat, l7rira, manswlch, li9a7]
# 1                                                          [congé, inchallah, allah, li9a7]
# 2                                               [aydiro, li9a7, drarga, hhhhhhhhhhhhhhhhhh]
# 3    [Yomkino, najid, 3ilaj, lakin, 5alfiyat, li9a7, tkono, tawil, 5atira, yomkin, tousbib]
# 4                                                            [sa7bi, srbilna, li9a7, ghdda]
# Name: cleaned_tweets, dtype: object

# %%
combine.head(5)
# Out:
#      username  \
# 0    hihilist
# 1    Amine19O
# 2    notcidji
# 3  NaimHamdi8
# 4     HiIsBah
#
#                                                                                                                   tweet  \
# 0                                                         Nswl 3la moukwinat dual had l7rira ou manswlch 3la dyal li9a7
# 1                                                   @Docteur_WHOO L congé inchallah bi idni allah men be3d ma yji li9a7
# 2                                                                              aydiro li9a7 f drarga hhhhhhhhhhhhhhhhhh
# 3  Yomkino an najid 3ilaj il vrus .... wa lakin 5alfiyat li9a7 tkono 3al mada tawil 5atira ou yomkin ana tousbib fi ta…
# 4                                                            @zyadelassad33 sa7bi srbilna li9a7 rah 3ndi frd dsvt ghdda
#
#    label  \
# 0      0
# 1      1
# 2      0
# 3      0
# 4      2
#
#                                                                cleaned_tweets
# 0                                             moukwinat l7rira manswlch li9a7
# 1                                                 congé inchallah allah li9a7
# 2                                      aydiro li9a7 drarga hhhhhhhhhhhhhhhhhh
# 3  Yomkino najid 3ilaj lakin 5alfiyat li9a7 tkono tawil 5atira yomkin tousbib
# 4                                                   sa7bi srbilna li9a7 ghdda

# %% [markdown]
# # Tweets visualization

# %%
# visualizing all the words our data using WordCloud plot
from wordcloud import WordCloud
words=' '.join([text for text in combine['cleaned_tweets']])
wordcloud=WordCloud(width=800,height=500,random_state=20,max_font_size=110).generate(words)
plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#separate wordclouds for both classes.
# words in negative twets
simple_tweets=' '.join([text for text in combine['cleaned_tweets'][combine['label']==0]])
wordcloud=WordCloud(width=800,height=500,random_state=20,max_font_size=110).generate(simple_tweets)
plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#separate wordclouds for both classes.
# words in positive twets
simple_tweets=' '.join([text for text in combine['cleaned_tweets'][combine['label']==1]])
wordcloud=WordCloud(width=800,height=500,random_state=20,max_font_size=110).generate(simple_tweets)
plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#separate wordclouds for both classes.
# words in neutral twets
simple_tweets=' '.join([text for text in combine['cleaned_tweets'][combine['label']==2]])
wordcloud=WordCloud(width=800,height=500,random_state=20,max_font_size=110).generate(simple_tweets)
plt.figure(figsize=(10,7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# # Extracting Features from Cleaned Tweets

# %%
# using Bag Of Words
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')#set the parameter max_features = 1000 to select only top 1000 terms ordered by term frequency across the corpus.
# bag-of-words feature matrix
BOW = vectorizer.fit_transform(combine['cleaned_tweets'])
vectorizer,BOW
# Out:
# (CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                  dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                  lowercase=True, max_df=0.9, max_features=1000, min_df=2,
#                  ngram_range=(1, 1), preprocessor=None, stop_words='english',
#                  strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                  tokenizer=None, vocabulary=None),
#  <20x3 sparse matrix of type '<class 'numpy.int64'>'
#  	with 21 stored elements in Compressed Sparse Row format>)

# %% [markdown]
# # Modeling

# %%
from sklearn.model_selection import train_test_split
train_b=BOW[:9,:]
test_b=BOW[9:,:]
#splitting data into training and validation set
xtrain,xvalid,ytrain,yvalid=train_test_split(train_b,data['label'],random_state=42,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
RF=RandomForestClassifier(n_estimators=400,random_state=11).fit(xtrain,ytrain)
prediction=RF.predict(xvalid)
#validation score 
accuracy_score(yvalid,prediction)
# Out:
# 0.6666666666666666

# %%
# making prediction for the test dataset
test_p=RF.predict(test_b)
data1['label']=test_p
submission= data1[['tweet','label']]
submission.to_csv('result.csv',index=False)
